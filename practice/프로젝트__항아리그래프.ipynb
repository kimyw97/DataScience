# %% [markdown]
# <a href="https://colab.research.google.com/github/KimyYoungWook/DataScience/blob/main/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8__%ED%95%AD%EC%95%84%EB%A6%AC%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
import matplotlib.pyplot as plt
import csv
f= open('/content/201102_201102_연령별인구현황_월간.csv',encoding='cp949')
data =csv.reader(f)
m1=[]
f1=[]
for row in data:
  if '판교동' in row[0]:
    for i in row[3:104]:# 남성데이터 : 3~103번 데이터 슬라이싱 - 정수 데이터로 변환 -m 리스트에 저장
      m1.append(-int(i))
    for i in row[106:]:# 여성데이터 : 106번~ 끝까지 데이터 슬라이실 - 정수데이터로 변환 - f리스트에 저장
      f1.append(int(i))
f.close
f= open('/content/202102_202102_연령별인구현황_월간.csv',encoding='cp949')
data =csv.reader(f)
m2=[]
f2=[]
for row in data:
  if '판교동' in row[0]:
    for i in row[3:104]:# 남성데이터 : 3~103번 데이터 슬라이싱 - 정수 데이터로 변환 -m 리스트에 저장
      m2.append(-int(i))
    for i in row[106:]:# 여성데이터 : 106번~ 끝까지 데이터 슬라이실 - 정수데이터로 변환 - f리스트에 저장
      f2.append(int(i))
plt.figure(dpi=100)
plt.style.use('ggplot')
plt.rc('font', family='NanumBarunGothic') 
plt.title("2011, 2021 판교신도시 남녀 인구 분포")
plt.barh(range(101),m2,color='r',label='2021_남')
plt.barh(range(101),f2,color='b',label='2021_여')
plt.barh(range(101),m1,color='pink',label='2011_남')
plt.barh(range(101),f1,color='skyblue',label='2011_여')
plt.xlabel('인구 수')
plt.ylabel('나이')
plt.legend(loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.plot(m1*(-1)+f1,color='y',label='2011_판교')
plt.plot(m2*(-1)+f2,color='g',label='2021_판교')
plt.title("2011, 2021 판교신도시 인구 분포")
plt.ylabel('인구 수')
plt.xlabel('나이')
plt.style.use('ggplot')
plt.legend()

# %%
import matplotlib.pyplot as plt
import csv
f= open('/content/202102_202102_연령별인구현황_월간.csv',encoding='cp949')
data =csv.reader(f)
m=[]
f=[]
for row in data:
  if '판교동' in row[0]:
    for i in row[3:104]:# 남성데이터 : 3~103번 데이터 슬라이싱 - 정수 데이터로 변환 -m 리스트에 저장
      m.append(-int(i))
    for i in row[106:]:# 여성데이터 : 106번~ 끝까지 데이터 슬라이실 - 정수데이터로 변환 - f리스트에 저장
      f.append(int(i))
plt.figure(dpi=100)
plt.rc('font', family='NanumBarunGothic') 
plt.barh(range(101),m,color='r')
plt.barh(range(101),f)
plt.show()
