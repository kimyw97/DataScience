# %% [markdown]
# <a href="https://colab.research.google.com/github/KimyYoungWook/DataScience/blob/main/%EC%A7%80%ED%95%98%EC%B2%A0_%EC%8B%9C%EA%B0%84%EB%8C%80%EB%B3%84%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 지하철 시간대별 이용 현황 데이터 정제하기

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
for row in data:
  print(row)

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
for row in data:
  row[4:] =map(int,row[4:])

# %% [markdown]
# 출근 시간대 사람들이 가장 많이 타고 내리는 역은 어디일까

# %% [markdown]
# 아침 7시 승차 데이터 추출 -> 10번 인덱스 데이터 값 추출

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
result=[] # 아침 7시 승차 데이터 추출 -> 10번 인덱스에 존재
for row in data:
  row[4:] =map(int,row[4:])
  result.append(row[10])
print(len(result))
print(result)
# Out:
# 598
# ...

# %% [markdown]
# 아침 7시 승차 데이터 막대 그래프로 표현하기

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
result=[] # 아침 7시 승차 데이터 추출 -> 10번 인덱스에 존재
for row in data:
  row[4:] =map(int,row[4:])
  result.append(row[10])
plt.figure(dpi=150)
plt.style.use('ggplot')
plt.bar(range(len(result)),result)
# Out:
# <BarContainer object of 598 artists>

# %% [markdown]
# 오름차순으로 데이터 정렬하여 그래프 그리기

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
result=[] # 아침 7시 승차 데이터 추출 -> 10번 인덱스에 존재
for row in data:
  row[4:] =map(int,row[4:])
  result.append(row[10])
result.sort()
plt.figure(dpi=150)
plt.style.use('ggplot')
plt.bar(range(len(result)),result)
# Out:
# <BarContainer object of 598 artists>

# %% [markdown]
# 출근시간 (7-9시) 막대 그래프 그리기

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
result=[] # 아침 7시 승차 데이터 추출 -> 10번 인덱스에 존재
for row in data:
  row[4:] =map(int,row[4:])
  result.append(sum(row[10:15:2]))#10 12 4를 추출
result.sort()
plt.figure(dpi=150)
plt.style.use('ggplot')
plt.bar(range(len(result)),result)
# Out:
# <BarContainer object of 598 artists>

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
mx=0;
mx_station=0
result=[] # 아침 7시 승차 데이터 추출 -> 10번 인덱스에 존재
for row in data:
  row[4:] =map(int,row[4:])
  if sum(row[10:15:2]) >mx:
    mx=sum(row[10:15:2])
    mx_station= row[3]+'(' +row[1]+')'
print(mx_station,mx)
# Out:
# 신림(2호선) 809541

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
mx_ride=0;
mx_quit=0
mx_station_ride=0
mx_station_quit=0
result=[] # 아침 7시 승차 데이터 추출 -> 10번 인덱스에 존재
for row in data:
  row[4:] =map(int,row[4:])
  result.append(sum(row[32:36:2]))
  if sum(row[32:36:2]) > mx_ride:
    mx_ride=sum(row[32:36:2])
    mx_station_ride= row[3]+'(' +row[1]+')'
  if sum(row[33:36:2]) > mx_quit:
    mx_quit=sum(row[33:36:2])
    mx_station_quit=row[3]+'(' +row[1]+')'
result.sort()
plt.figure(dpi=150)
plt.style.use('ggplot')
plt.bar(range(len(result)),result)
print(mx_station_ride,mx_ride)
print(mx_station_quit,mx_quit)
# Out:
# 강남(2호선) 723636
# 신림(2호선) 561336

# %% [markdown]
# 밤 11시에 사람들이 가장 많이 타는 역은 어디일까

# %% [markdown]
# 승차 패턴 찾기<br>
# 승차 시각이 1시간씩 늦어질 때 마다 인덱스 2씩 늘어남 <br> 승차 시작 시간의 인덱스 값 4 -> 4시부터 승차가 시작(첫차)<br>
# 승차 시각(t) 와 승차 인원이 적힌 인덱스(i) 관계 분석 <br>
# i = 4 + (t -4) * 2

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
mx=0;
mx_station=''
t = int(input('몇시의 승차인원이 가장 많은 역이 궁금하세요? : '))
for row in data:
  row[4:] =map(int,row[4:])
  a = row[4 + (t-4)*2] #입력 받은 시각의 승차인원 값 추출
  if a>mx :
    mx=a
    mx_station =row[3]+'(' +row[1]+')'

print(mx_station,mx)
# Out:
# 몇시의 승차인원이 가장 많은 역이 궁금하세요? : 16
# 강남(2호선) 227268

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %% [markdown]
# 시간대별 최대 승차역 이름 및 승차 인원 막대 그래프로 표현하기

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
mx=[0]*24
mx_station=['']*24
for row in data:
  row[4:] =map(int,row[4:])
  for j in range(24):
    a = row[j*2 +4 ] # 시간대별 패던 i=j*2 +4 (j는 0~23까지) -> 시작 인덱스 4
    if a>mx[j]:
      mx[j]=a
      mx_station[j]=row[3]

print(mx_station)
plt.rc('font', family='NanumBarunGothic') 
plt.figure(dpi=200)
plt.bar(range(24),mx)
plt.xticks(range(24),mx_station,rotation=90)
plt.show()
# Out:
# ['구로', '홍대입구', '신림', '신림', '신림', '신림', '신림', '신림', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '성신여대입구(돈암)', '신방화']
# 3

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
mx=[0]*24
mx_station=['']*24
for row in data:
  row[4:] =map(int,row[4:])
  for j in range(24):
    a = row[j*2 +4 ] # 시간대별 패던 i=j*2 +4 (j는 0~23까지) -> 시작 인덱스 4
    if a>mx[j]:
      mx[j]=a
      mx_station[j]=row[3] +'(' + str(j+4) + ')'

plt.rc('font', family='NanumBarunGothic') 
plt.figure(dpi=200)
plt.bar(range(24),mx)
plt.style.use('ggplot')
plt.xticks(range(24),mx_station,rotation=90)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)
mx=[0]*24
mx_station=['']*24
for row in data:
  row[4:] =map(int,row[4:])
  for j in range(24):
    a = row[j*2 +5 ] # 시간대별 패던 i=j*2 +4 (j는 0~23까지) -> 시작 인덱스 4
    if a>mx[j]:
      mx[j]=a
      mx_station[j]=row[3] +'(' + str(j+5) + ')'

plt.rc('font', family='NanumBarunGothic') 
plt.figure(dpi=200)
plt.bar(range(24),mx)
plt.style.use('ggplot')
plt.xticks(range(24),mx_station,rotation=90)
plt.show()

# %% [markdown]
# 모든 지하철역에서 시간대별 승하차 인원을 모두 더하면

# %%
import csv
import matplotlib.pyplot as plt
f=open('subwaytime.csv')
data=csv.reader(f)
next(data)
next(data)

s_in =[0]*24
s_out=[0]*24
for row in data:
  row[4:] =map(int,row[4:])
  for j in range(24):
    s_in[j] +=row[4+j*2] #승차
    s_out[j] +=row[5+j*2]#하차

plt.rc('font', family='NanumBarunGothic') 
plt.figure(dpi=200)
plt.style.use('ggplot')
plt.title('지하철 시간대별 승하차 인원 추이')
plt.plot(s_in, label='승차')
plt.plot(s_out, label='하차')
plt.legend()
plt.xticks(range(24),range(4,28))
plt.show()
